# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import sys
import os
from tqdm import tqdm
sys.path.append(os.path.join(os.path.expanduser('~'), 'projects'))
from j_utils import munging as mg
from j_utils import eval_results as er
import lc_utils
# from fastai.structured import *

pd.options.display.max_columns = 999
# pd.options.display.max_rows = 999
pd.options.display.max_seq_items = None
# np.set_printoptions(threshold=100)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-3-fb923d42e24d> in <module>
#       5 from j_utils import munging as mg
#       6 from j_utils import eval_results as er
# ----> 7 import lc_utils
#       8 # from fastai.structured import *
#       9
#
# ModuleNotFoundError: No module named 'lc_utils'

# %%
PATH = dc.data_path
project = 'lendingclub'
fname_base_loan = 'base_loan_info.fth'
fname_eval_loan = 'eval_loan_info.fth'
fname_str_loan = 'str_loan_info.fth'
fname_scl_pmt = 'scaled_pmt_hist.fth'
data_path = f'{PATH}{project}'

# %%
# load in and drop fico low
base_loan_info = pd.read_feather(f'{data_path}/base_loan_info.fth')
base_loan_info.drop('fico_range_low', axis=1, inplace=True)
eval_loan_info = pd.read_feather(f'{data_path}/eval_loan_info.fth')
str_loan_info = pd.read_feather(f'{data_path}/str_loan_info.fth')
# base_loan_info = pd.read_feather(f'{data_path}/base_loan_info_w_newfeats.fth')

# %%
# add in some more ratio features
lc_utils.add_custom_lc_features(base_loan_info)

# %%
base_loan_info, eval_loan_info = lc_utils.split_out_traintestable_loans(base_loan_info, eval_loan_info)

# %%
cut_date = lc_utils.get_split_date(eval_loan_info, 'issue_d', .8)

# %%
test_ids = eval_loan_info[eval_loan_info['issue_d'] >= cut_date]['id'].values
test_df = base_loan_info[base_loan_info['id'].isin(test_ids)].copy()
train_df = base_loan_info[~base_loan_info['id'].isin(test_ids)].copy()
train_ids = train_df['id'].values

# %% [markdown]
# # justin via munging

# %%
print(train_df.shape, train_df.dtypes.value_counts(dropna=False))
train_df, max_dict, min_dict, new_null_colnames, fill_dict, cats_dict, norm_dict = mg.train_proc(train_df, normalize=True, verbose=False)
print(train_df.shape, train_df.dtypes.value_counts(dropna=False))
# Out:
# (916089, 107) float64           91
# object            12
# int64              2
# datetime64[ns]     2
# dtype: int64
# (916089, 162) float64    81
# int64      68
# int8       10
# bool        2
# int16       1
# dtype: int64

# %%
print(test_df.shape, test_df.dtypes.value_counts(dropna=False))
test_df = mg.val_test_proc(test_df, train_df.columns, max_dict, min_dict, fill_dict, cats_dict, norm_dict=norm_dict, verbose=False)
print(test_df.shape, test_df.dtypes.value_counts(dropna=False))
# Out:
# (235079, 107) float64           91
# object            12
# int64              2
# datetime64[ns]     2
# dtype: int64
# (235079, 162) float64    120
# int64       29
# int8        10
# bool         2
# int16        1
# dtype: int64

# %%
train_df.loc[[0,4],:]
# Out:
#    application_type  inq_last_12m  num_bc_tl  num_rev_accts  tot_coll_amt  \
# 0                 1     -0.157570  -0.285975      -0.245054     -0.023126
# 4                 1     -0.540488  -1.317487      -1.479975     -0.023126
#
#     bc_util  open_rv_24m  num_bc_sats  mths_since_rcnt_il  \
# 0  0.146868    -0.051326    -0.251438           -0.336666
# 4 -0.999984    -0.786824    -0.949760           -0.178477
#
#    mths_since_last_delinq  max_bal_bc  num_il_tl  mo_sin_rcnt_tl  purpose  \
# 0               -0.147913   -0.241297  -0.201760       -0.221266        3
# 4               -0.147913   -0.700158  -0.475442        0.452284        5
#
#    sub_grade  total_bal_ex_mort  acc_now_delinq        id  num_tl_90g_dpd_24m  \
# 0          9          -0.256165       -0.065073 -1.405230            -0.18119
# 4          2          -0.613251       -0.065073 -1.405175            -0.18119
#
#         dti  mths_since_recent_bc  open_act_il  delinq_amnt  inq_last_6_mths  \
# 0  0.162436             -0.333212    -0.278067    -0.018428        -0.701677
# 4 -0.845721             -0.267544    -0.278067    -0.018428        -0.701677
#
#    mths_since_last_major_derog  mo_sin_old_il_acct  open_acc  \
# 0                    -0.014089            0.050087 -0.288108
# 4                    -0.014089            0.765405 -1.225332
#
#    acc_open_past_24_mths  annual_inc  total_bc_limit  addr_state  revol_bal  \
# 0              -0.182082    0.153951       -0.305738           5   0.554204
# 4              -0.506279   -0.149054       -0.594095          30  -0.604746
#
#    open_acc_6m  is_inc_v  mths_since_recent_revol_delinq  annual_inc_joint  \
# 0    -0.103625         2                       -0.133373         -0.152689
# 4    -0.898724         1                       -0.133373         -0.152689
#
#    all_util  total_il_high_credit_limit  num_accts_ever_12_0_ppd  open_il_24m  \
# 0  0.078137                    -0.24012                -0.388387    -0.451844
# 4  0.127838                    -0.39936                -0.388387    -0.451844
#
#    num_tl_12_0dpd_2m  total_bal_il  i_l_util  open_rv_12m  \
# 0          -0.027113     -0.268464  0.156402    -0.302638
# 4          -0.027113     -0.451037  0.022182    -0.932545
#
#    mths_since_recent_inq  num_sats  tax_liens  mths_since_recent_bc_dlq  \
# 0              -0.300117 -0.117594  -0.125256                 -0.047458
# 4              -0.640900 -1.239276  -0.125256                 -0.047458
#
#    num_actv_bc_tl  num_actv_rev_tl  total_acc  pct_tl_nvr_dlq  \
# 0       -0.310990        -0.230773   1.406432        0.436794
# 4       -0.762976        -1.151850  -1.196423        0.671857
#
#    total_rev_hi_lim  mths_since_last_record  num_tl_30dpd   pub_rec  \
# 0         -0.225879               -0.001100     -0.055589 -0.343726
# 4         -0.624387               -1.015091     -0.055589  1.346688
#
#    tot_hi_cred_lim  delinq_2_yrs      term  loan_amount  total_cu_tl  \
# 0        -0.351699     -0.363033 -0.562151     1.259278    -0.574707
# 4        -0.474447     -0.363033 -0.562151    -0.757985    -0.574707
#
#    fico_range_high  avg_cur_bal  chargeoff_within_12_mths  grade  open_il_12m  \
# 0         1.296266    -0.374541                 -0.082483      2     0.146272
# 4         0.323663     0.100552                 -0.082483      1    -0.802464
#
#    tot_cur_bal  collections_12_mths_ex_med  pub_rec_bankruptcies  installment  \
# 0    -0.390011                   -0.109137             -0.340898     1.561087
# 4    -0.415678                   -0.109137              2.372008    -0.761851
#
#    num_tl_op_past_12m  dti_joint  mo_sin_rcnt_rev_tl_op  int_rate  emp_length  \
# 0           -0.070012  -0.060619              -0.313943 -0.274585          11
# 4           -0.631068  -0.060619               0.180068 -1.479446           2
#
#      inq_fi  disbursement_method  num_op_rev_tl  revol_util  percent_bc_gt_75  \
# 0 -0.666721                    1      -0.294659   -0.082018          0.043510
# 4  0.600639                    1      -1.420174   -0.777763         -1.361649
#
#    num_rev_tl_bal_gt_0  addr_zip  bc_open_to_buy  home_ownership  mort_acc  \
# 0            -0.222917       879       -0.358392               4 -0.354871
# 4            -1.163525       649       -0.259521               1  0.609561
#
#    initial_list_status  mo_sin_old_rev_tl_op  monthly_inc  dti_w_loan  \
# 0                    1             -0.180228     0.153951    0.475390
# 4                    2             -1.583569    -0.149054   -0.998063
#
#    delinq_to_monthly_inc  tot_cur_bal_to_monthly_inc  loan_to_inc  \
# 0              -0.016502                   -0.004358    -0.004172
# 4              -0.016502                   -0.004359    -0.004194
#
#    earliest_cr_lineYear  earliest_cr_lineMonth  earliest_cr_lineWeek  \
# 0                  1994                      2                     5
# 4                  2002                      3                     9
#
#    earliest_cr_lineDayofweek  earliest_cr_lineDayofyear  \
# 0                          1                         32
# 4                          4                         60
#
#    earliest_cr_lineIs_quarter_start  earliest_cr_lineIs_year_start  \
# 0                             False                          False
# 4                             False                          False
#
#    inq_last_12m_isnull  num_bc_tl_isnull  num_rev_accts_isnull  \
# 0                    1                 1                     1
# 4                    0                 0                     0
#
#    tot_coll_amt_isnull  bc_util_isnull  open_rv_24m_isnull  \
# 0                    1               1                   1
# 4                    0               0                   0
#
#    num_bc_sats_isnull  mths_since_rcnt_il_isnull  \
# 0                   1                          1
# 4                   0                          0
#
#    mths_since_last_delinq_isnull  max_bal_bc_isnull  num_il_tl_isnull  \
# 0                              1                  1                 1
# 4                              1                  0                 0
#
#    mo_sin_rcnt_tl_isnull  total_bal_ex_mort_isnull  num_tl_90g_dpd_24m_isnull  \
# 0                      1                         1                          1
# 4                      0                         0                          0
#
#    dti_isnull  mths_since_recent_bc_isnull  open_act_il_isnull  \
# 0           0                            1                   1
# 4           0                            0                   0
#
#    mths_since_last_major_derog_isnull  mo_sin_old_il_acct_isnull  \
# 0                                   1                          1
# 4                                   1                          0
#
#    acc_open_past_24_mths_isnull  total_bc_limit_isnull  is_inc_v_joint_isnull  \
# 0                             1                      1                      1
# 4                             0                      0                      1
#
#    open_acc_6m_isnull  mths_since_recent_revol_delinq_isnull  \
# 0                   1                                      1
# 4                   0                                      1
#
#    annual_inc_joint_isnull  all_util_isnull  \
# 0                        1                1
# 4                        1                0
#
#    total_il_high_credit_limit_isnull  num_accts_ever_12_0_ppd_isnull  \
# 0                                  1                               1
# 4                                  0                               0
#
#    open_il_24m_isnull  num_tl_12_0dpd_2m_isnull  total_bal_il_isnull  \
# 0                   1                         1                    1
# 4                   0                         0                    0
#
#    i_l_util_isnull  open_rv_12m_isnull  mths_since_recent_inq_isnull  \
# 0                1                   1                             1
# 4                0                   0                             0
#
#    num_sats_isnull  mths_since_recent_bc_dlq_isnull  num_actv_bc_tl_isnull  \
# 0                1                                1                      1
# 4                0                                1                      0
#
#    num_actv_rev_tl_isnull  pct_tl_nvr_dlq_isnull  total_rev_hi_lim_isnull  \
# 0                       1                      1                        1
# 4                       0                      0                        0
#
#    mths_since_last_record_isnull  num_tl_30dpd_isnull  tot_hi_cred_lim_isnull  \
# 0                              1                    1                       1
# 4                              0                    0                       0
#
#    total_cu_tl_isnull  avg_cur_bal_isnull  open_il_12m_isnull  \
# 0                   1                   1                   1
# 4                   0                   0                   0
#
#    tot_cur_bal_isnull  pub_rec_bankruptcies_isnull  num_tl_op_past_12m_isnull  \
# 0                   1                            0                          1
# 4                   0                            0                          0
#
#    dti_joint_isnull  mo_sin_rcnt_rev_tl_op_isnull  emp_length_isnull  \
# 0                 1                             1                  0
# 4                 1                             0                  0
#
#    inq_fi_isnull  num_op_rev_tl_isnull  revol_util_isnull  \
# 0              1                     1                  0
# 4              0                     0                  0
#
#    percent_bc_gt_75_isnull  num_rev_tl_bal_gt_0_isnull  bc_open_to_buy_isnull  \
# 0                        1                           1                      1
# 4                        0                           0                      0
#
#    mort_acc_isnull  mo_sin_old_rev_tl_op_isnull  dti_w_loan_isnull  \
# 0                1                            1                  0
# 4                0                            0                  0
#
#    delinq_to_monthly_inc_isnull  tot_cur_bal_to_monthly_inc_isnull
# 0                             0                                  1
# 4                             0                                  0

# %%
test_df.loc[[2,4053],:]
# Out:
#       application_type  inq_last_12m  num_bc_tl  num_rev_accts  tot_coll_amt  \
# 2                    1      1.374103   1.777049       1.236850     -0.023126
# 4053                 1      0.225348  -0.904882      -0.368546     -0.023126
#
#        bc_util  open_rv_24m  num_bc_sats  mths_since_rcnt_il  \
# 2     0.592460     3.626165     3.240171            1.205678
# 4053  1.264501    -0.786824    -1.298921           -0.297119
#
#       mths_since_last_delinq  max_bal_bc  num_il_tl  mo_sin_rcnt_tl  purpose  \
# 2                  -0.147913   -0.770163   0.345604       -0.109008        3
# 4053               -0.695323    0.791056   1.577174       -0.445783       10
#
#       sub_grade  total_bal_ex_mort  acc_now_delinq        id  \
# 2            24          -0.871936       -0.065073 -1.405191
# 4053         13           2.250815       -0.065073 -1.392050
#
#       num_tl_90g_dpd_24m       dti  mths_since_recent_bc  open_act_il  \
# 2               -0.18119 -0.131610             -0.563048    -0.610098
# 4053            -0.18119  0.862545              5.511207     1.050054
#
#       delinq_amnt  inq_last_6_mths  mths_since_last_major_derog  \
# 2       -0.018428         3.292193                    -0.579417
# 4053    -0.018428         0.296791                    -0.014089
#
#       mo_sin_old_il_acct  open_acc  acc_open_past_24_mths  annual_inc  \
# 2               0.649407  0.461671               2.735690   -0.667435
# 4053            0.050087 -0.288108              -0.506279   -0.073303
#
#       total_bc_limit  addr_state  revol_bal  open_acc_6m  is_inc_v  \
# 2          -0.697423          48  -0.387818    -0.898724         1
# 4053       -0.493170          32  -0.009171    -0.103625         2
#
#       mths_since_recent_revol_delinq  annual_inc_joint  all_util  \
# 2                          -0.133373         -0.152689  0.674540
# 4053                        1.159004         -0.152689  0.923041
#
#       total_il_high_credit_limit  num_accts_ever_12_0_ppd  open_il_24m  \
# 2                      -0.826025                 0.400655    -1.018419
# 4053                    2.409390                -0.388387     0.114731
#
#       num_tl_12_0dpd_2m  total_bal_il  i_l_util  open_rv_12m  \
# 2             -0.027113     -0.856894 -2.885924     1.587082
# 4053          -0.027113      2.426730  0.380103    -0.302638
#
#       mths_since_recent_inq  num_sats  tax_liens  mths_since_recent_bc_dlq  \
# 2                 -0.811291  0.443247  -0.125256                 -0.047458
# 4053              -0.470508 -0.304541  -0.125256                 -0.047458
#
#       num_actv_bc_tl  num_actv_rev_tl  total_acc  pct_tl_nvr_dlq  \
# 2           1.496953         2.225435   0.902654       -2.971614
# 4053       -1.214962        -1.151850   0.566802       -0.797285
#
#       total_rev_hi_lim  mths_since_last_record  num_tl_30dpd   pub_rec  \
# 2            -0.566884               -1.522087     -0.055589  1.346688
# 4053         -0.276695               -0.001100     -0.055589 -0.343726
#
#       tot_hi_cred_lim  delinq_2_yrs      term  loan_amount  total_cu_tl  \
# 2           -0.879186     -0.363033 -0.562151    -1.291967     0.811006
# 4053        -0.038217      1.952158 -0.562151    -0.710520     0.118149
#
#       fico_range_high  avg_cur_bal  chargeoff_within_12_mths  grade  \
# 2           -0.973140    -0.790756                 -0.082483      5
# 4053        -0.162638     0.234091                 -0.082483      3
#
#       open_il_12m  tot_cur_bal  collections_12_mths_ex_med  \
# 2       -0.802464    -0.842313                   -0.109137
# 4053     0.146272     0.093377                   -0.109137
#
#       pub_rec_bankruptcies  installment  num_tl_op_past_12m  dti_joint  \
# 2                 2.372008    -1.183618            1.052099  -0.060619
# 4053             -0.340898    -0.595173           -0.070012  -0.060619
#
#       mo_sin_rcnt_rev_tl_op  int_rate  emp_length    inq_fi  \
# 2                 -0.375694  2.648319          11  0.600639
# 4053              -0.560948  0.193972           8 -0.033041
#
#       disbursement_method  num_op_rev_tl  revol_util  percent_bc_gt_75  \
# 2                       1       1.055959    0.830366          1.046794
# 4053                    1      -0.969968    0.905356          1.448669
#
#       num_rev_tl_bal_gt_0  addr_zip  bc_open_to_buy  home_ownership  mort_acc  \
# 2                2.285373       921       -0.580517               4 -0.837086
# 4053            -1.163525        62       -0.624732               4 -0.837086
#
#       initial_list_status  mo_sin_old_rev_tl_op  monthly_inc  dti_w_loan  \
# 2                       2             -0.598016    -0.667435   -0.344348
# 4053                    2              0.098298    -0.073303    0.402428
#
#       delinq_to_monthly_inc  tot_cur_bal_to_monthly_inc  loan_to_inc  \
# 2                 -0.016502                   -0.004369    -0.004196
# 4053              -0.016502                   -0.004347    -0.004195
#
#       earliest_cr_lineYear  earliest_cr_lineMonth  earliest_cr_lineWeek  \
# 2                     2003                      4                    14
# 4053                  2000                      8                    31
#
#       earliest_cr_lineDayofweek  earliest_cr_lineDayofyear  \
# 2                             1                         91
# 4053                          1                        214
#
#       earliest_cr_lineIs_quarter_start  earliest_cr_lineIs_year_start  \
# 2                                 True                          False
# 4053                             False                          False
#
#       inq_last_12m_isnull  num_bc_tl_isnull  num_rev_accts_isnull  \
# 2                     1.0               0.0                   0.0
# 4053                  1.0               0.0                   0.0
#
#       tot_coll_amt_isnull  bc_util_isnull  open_rv_24m_isnull  \
# 2                     0.0               0                 1.0
# 4053                  0.0               0                 1.0
#
#       num_bc_sats_isnull  mths_since_rcnt_il_isnull  \
# 2                    0.0                          0
# 4053                 0.0                          0
#
#       mths_since_last_delinq_isnull  max_bal_bc_isnull  num_il_tl_isnull  \
# 2                                 1                1.0               0.0
# 4053                              0                1.0               0.0
#
#       mo_sin_rcnt_tl_isnull  total_bal_ex_mort_isnull  \
# 2                       0.0                       0.0
# 4053                    0.0                       0.0
#
#       num_tl_90g_dpd_24m_isnull  dti_isnull  mths_since_recent_bc_isnull  \
# 2                           0.0           0                            0
# 4053                        0.0           0                            0
#
#       open_act_il_isnull  mths_since_last_major_derog_isnull  \
# 2                    1.0                                   0
# 4053                 1.0                                   1
#
#       mo_sin_old_il_acct_isnull  acc_open_past_24_mths_isnull  \
# 2                             0                           0.0
# 4053                          0                           0.0
#
#       total_bc_limit_isnull  is_inc_v_joint_isnull  open_acc_6m_isnull  \
# 2                       0.0                      1                 1.0
# 4053                    0.0                      1                 1.0
#
#       mths_since_recent_revol_delinq_isnull  annual_inc_joint_isnull  \
# 2                                         1                        1
# 4053                                      0                        1
#
#       all_util_isnull  total_il_high_credit_limit_isnull  \
# 2                   0                                0.0
# 4053                0                                0.0
#
#       num_accts_ever_12_0_ppd_isnull  open_il_24m_isnull  \
# 2                                0.0                 1.0
# 4053                             0.0                 1.0
#
#       num_tl_12_0dpd_2m_isnull  total_bal_il_isnull  i_l_util_isnull  \
# 2                            1                  1.0                0
# 4053                         0                  1.0                0
#
#       open_rv_12m_isnull  mths_since_recent_inq_isnull  num_sats_isnull  \
# 2                    1.0                             0              0.0
# 4053                 1.0                             0              0.0
#
#       mths_since_recent_bc_dlq_isnull  num_actv_bc_tl_isnull  \
# 2                                   1                    0.0
# 4053                                1                    0.0
#
#       num_actv_rev_tl_isnull  pct_tl_nvr_dlq_isnull  total_rev_hi_lim_isnull  \
# 2                        0.0                    0.0                      0.0
# 4053                     0.0                    0.0                      0.0
#
#       mths_since_last_record_isnull  num_tl_30dpd_isnull  \
# 2                                 0                  0.0
# 4053                              1                  0.0
#
#       tot_hi_cred_lim_isnull  total_cu_tl_isnull  avg_cur_bal_isnull  \
# 2                        0.0                 1.0                   0
# 4053                     0.0                 1.0                   0
#
#       open_il_12m_isnull  tot_cur_bal_isnull  pub_rec_bankruptcies_isnull  \
# 2                    1.0                 0.0                          0.0
# 4053                 1.0                 0.0                          0.0
#
#       num_tl_op_past_12m_isnull  dti_joint_isnull  \
# 2                           0.0                 1
# 4053                        0.0                 1
#
#       mo_sin_rcnt_rev_tl_op_isnull  emp_length_isnull  inq_fi_isnull  \
# 2                              0.0                  0            1.0
# 4053                           0.0                  0            1.0
#
#       num_op_rev_tl_isnull  revol_util_isnull  percent_bc_gt_75_isnull  \
# 2                      0.0                  0                        0
# 4053                   0.0                  0                        0
#
#       num_rev_tl_bal_gt_0_isnull  bc_open_to_buy_isnull  mort_acc_isnull  \
# 2                            0.0                      0              0.0
# 4053                         0.0                      0              0.0
#
#       mo_sin_old_rev_tl_op_isnull  dti_w_loan_isnull  \
# 2                             0.0                  0
# 4053                          0.0                  0
#
#       delinq_to_monthly_inc_isnull  tot_cur_bal_to_monthly_inc_isnull
# 2                                0                                0.0
# 4053                             0                                0.0

# %%
base_loan_info.loc[[0,4,2,4053],[col for col in train_df.columns if col in base_loan_info.columns]]
# Out:
#      application_type  inq_last_12m  num_bc_tl  num_rev_accts  tot_coll_amt  \
# 0          individual           NaN        NaN            NaN           NaN
# 4          individual           1.0        2.0            3.0           0.0
# 2          individual           6.0       17.0           25.0           0.0
# 4053       individual           3.0        4.0           12.0           0.0
#
#       bc_util  open_rv_24m  num_bc_sats  mths_since_rcnt_il  \
# 0         NaN          NaN          NaN                 NaN
# 4       0.354          1.0          2.0                15.0
# 2       0.790         13.0         14.0                50.0
# 4053    0.974          1.0          1.0                12.0
#
#       mths_since_last_delinq  max_bal_bc  num_il_tl  mo_sin_rcnt_tl  \
# 0                        NaN         NaN        NaN             NaN
# 4                        NaN      1569.0        5.0            12.0
# 2                        NaN      1158.0       11.0             7.0
# 4053                    19.0     10324.0       20.0             4.0
#
#                  purpose sub_grade  total_bal_ex_mort  acc_now_delinq      id  \
# 0     debt_consolidation        B4                NaN             0.0   54734
# 4       home_improvement        A2            20302.0             0.0   56121
# 2     debt_consolidation        E4             8351.0             0.0   55716
# 4053               other        C3           152619.0             0.0  390858
#
#       num_tl_90g_dpd_24m     dti  mths_since_recent_bc  open_act_il  \
# 0                    NaN  0.1948                   NaN          NaN
# 4                    0.0  0.1084                  16.0          2.0
# 2                    0.0  0.1696                   7.0          1.0
# 4053                 0.0  0.2548                 192.0          6.0
#
#       delinq_amnt  inq_last_6_mths  mths_since_last_major_derog  \
# 0             0.0              0.0                          NaN
# 4             0.0              0.0                          NaN
# 2             0.0              4.0                         31.0
# 4053          0.0              1.0                          NaN
#
#       mo_sin_old_il_acct  open_acc  acc_open_past_24_mths  annual_inc  \
# 0                    NaN      10.0                    NaN     85000.0
# 4                  166.0       5.0                    3.0     65000.0
# 2                  160.0      14.0                   13.0     30784.0
# 4053               129.0      10.0                    3.0     70000.0
#
#       total_bc_limit addr_state  revol_bal  open_acc_6m  is_inc_v  \
# 0                NaN         CA    28854.0          NaN  platform
# 4             8500.0         NE     3012.0          0.0      none
# 2             6350.0         WA     7849.0          0.0      none
# 4053         10600.0         NJ    16292.0          1.0  platform
#
#       mths_since_recent_revol_delinq  annual_inc_joint  all_util  \
# 0                                NaN               NaN       NaN
# 4                                NaN               NaN      0.63
# 2                                NaN               NaN      0.74
# 4053                            62.0               NaN      0.79
#
#       total_il_high_credit_limit  num_accts_ever_12_0_ppd  open_il_24m  \
# 0                            NaN                      NaN          NaN
# 4                        23822.0                      0.0          1.0
# 2                         5929.0                      1.0          0.0
# 4053                    141612.0                      0.0          2.0
#
#       num_tl_12_0dpd_2m  total_bal_il  i_l_util  open_rv_12m  \
# 0                   NaN           NaN       NaN          NaN
# 4                   0.0       17290.0      0.73          0.0
# 2                   NaN         502.0      0.08          4.0
# 4053                0.0      136327.0      0.81          1.0
#
#       mths_since_recent_inq  num_sats  tax_liens  mths_since_recent_bc_dlq  \
# 0                       NaN       NaN        0.0                       NaN
# 4                       3.0       5.0        0.0                       NaN
# 2                       2.0      14.0        0.0                       NaN
# 4053                    4.0      10.0        0.0                       NaN
#
#       num_actv_bc_tl  num_actv_rev_tl  total_acc  pct_tl_nvr_dlq  \
# 0                NaN              NaN       42.0             NaN
# 4                2.0              2.0       11.0           1.000
# 2                7.0             13.0       36.0           0.690
# 4053             1.0              2.0       32.0           0.875
#
#       total_rev_hi_lim  mths_since_last_record  num_tl_30dpd  pub_rec  \
# 0                  NaN                     NaN           NaN      0.0
# 4               8500.0                    42.0           0.0      1.0
# 2              10650.0                    28.0           0.0      1.0
# 4053           21500.0                     NaN           0.0      0.0
#
#       tot_hi_cred_lim  delinq_2_yrs  term  loan_amount  total_cu_tl  \
# 0                 NaN           0.0    36      25000.0          NaN
# 4             87102.0           0.0    36       8000.0          0.0
# 2             16579.0           0.0    36       3500.0          4.0
# 4053         163112.0           2.0    36       8400.0          2.0
#
#       fico_range_high  avg_cur_bal  chargeoff_within_12_mths grade  \
# 0               739.0          NaN                       0.0     B
# 4               709.0      14826.0                       0.0     A
# 2               669.0        596.0                       0.0     E
# 4053            694.0      16958.0                       0.0     C
#
#       open_il_12m  tot_cur_bal  collections_12_mths_ex_med  \
# 0             NaN          NaN                         0.0
# 4             0.0      74131.0                         0.0
# 2             0.0       8351.0                         0.0
# 4053          1.0     152619.0                         0.0
#
#       pub_rec_bankruptcies  installment  num_tl_op_past_12m  dti_joint  \
# 0                      0.0   829.044904                 NaN        NaN
# 4                      1.0   245.155612                 1.0        NaN
# 2                      1.0   139.140880                 4.0        NaN
# 4053                   0.0   287.051294                 2.0        NaN
#
#       mo_sin_rcnt_rev_tl_op  int_rate emp_length  inq_fi disbursement_method  \
# 0                       NaN    0.1189   < 1 year     NaN                Cash
# 4                      16.0    0.0649  10+ years     2.0                Cash
# 2                       7.0    0.2499   < 1 year     2.0                Cash
# 4053                    4.0    0.1399    7 years     1.0                Cash
#
#       num_op_rev_tl  revol_util  percent_bc_gt_75  num_rev_tl_bal_gt_0  \
# 0               NaN       0.521               NaN                  NaN
# 4               2.0       0.354             0.000                  2.0
# 2              13.0       0.740             0.857                 13.0
# 4053            4.0       0.758             1.000                  2.0
#
#      addr_zip  bc_open_to_buy home_ownership  mort_acc initial_list_status  \
# 0       941xx             NaN           rent       NaN                   f
# 4       686xx          5488.0       mortgage       3.0                   w
# 2       984xx           907.0           rent       0.0                   w
# 4053    070xx           276.0           rent       0.0                   w
#
#       mo_sin_old_rev_tl_op  monthly_inc  dti_w_loan  delinq_to_monthly_inc  \
# 0                      NaN  7083.333333    0.311842                    0.0
# 4                     35.0  5416.666667    0.153659                    0.0
# 2                    127.0  2565.333333    0.223839                    0.0
# 4053                 192.0  5833.333333    0.304009                    0.0
#
#       tot_cur_bal_to_monthly_inc  loan_to_inc
# 0                            NaN     3.529412
# 4                      13.685723     1.476923
# 2                       3.255327     1.364345
# 4053                   26.163257     1.440000

# %%
cat_cols = [col for col in train_df.columns if col not in norm_dict['means'].keys()]

# %% [markdown]
# # What about hyperlearn using SVD for imputation?

# %%
import hyperlearn.hyperlearn.impute.SVDImpute as hpl_imp
# Out:
# Note that first time import of HyperLearn will be slow, since NUMBA code has to be compiled to machine code for optimization purposes.

# %%
train_copy = train_df.copy()
test_copy = test_df.copy()

# %%
train_copy, max_dict, min_dict, cats_dict, norm_dict = mg.train_hpl_proc(train_copy)
test_copy = mg.val_test_hpl_proc(test_copy, train_copy.columns, max_dict, min_dict, cats_dict)
# Out:
# dropping the following cols:
# ['revol_bal_joint', 'sec_app_mths_since_last_major_derog', 'sec_app_revol_util', 'sec_app_chargeoff_within_12_mths', 'sec_app_open_acc', 'sec_app_num_rev_accts', 'sec_app_collections_12_mths_ex_med', 'sec_app_fico_range_high', 'sec_app_fico_range_low', 'sec_app_open_act_il', 'sec_app_mort_acc', 'sec_app_inq_last_6_mths', 'sec_app_earliest_cr_lineYear', 'sec_app_earliest_cr_lineMonth', 'sec_app_earliest_cr_lineWeek', 'sec_app_earliest_cr_lineDay', 'sec_app_earliest_cr_lineDayofweek', 'sec_app_earliest_cr_lineDayofyear', 'sec_app_earliest_cr_lineIs_month_end', 'sec_app_earliest_cr_lineIs_month_start', 'sec_app_earliest_cr_lineIs_quarter_end', 'sec_app_earliest_cr_lineIs_quarter_start', 'sec_app_earliest_cr_lineIs_year_end', 'sec_app_earliest_cr_lineIs_year_start', 'earliest_cr_lineDay', 'earliest_cr_lineIs_month_end', 'earliest_cr_lineIs_month_start', 'earliest_cr_lineIs_quarter_end', 'earliest_cr_lineIs_year_end']
# only 2 values, consider dropping the following cols:
# ['application_type', 'is_inc_v_joint', 'term', 'disbursement_method', 'initial_list_status', 'earliest_cr_lineIs_quarter_start', 'earliest_cr_lineIs_year_start']

# %%
train_copy = train_copy.astype(float)
train_copy.dtypes.value_counts(dropna=False)
# Out:
# float64    100
# dtype: int64

# %%
test_copy = test_copy.astype(float)
test_copy.dtypes.value_counts(dropna=False)
# Out:
# float64    100
# dtype: int64

# %%
S, VT, mean, std, mins, standardise = hpl_imp.fit(train_copy.values)

# %%
train_svdimp = hpl_imp.transform(train_copy.values, S, VT, mean, std, mins, standardise)
train_svdimp = pd.DataFrame(train_svdimp)
train_svdimp.index = train_copy.index
train_svdimp.columns = train_copy.columns

# %%
test_svdimp = hpl_imp.transform(test_copy.values, S, VT, mean, std, mins, standardise)
test_svdimp = pd.DataFrame(test_svdimp)
test_svdimp.index = test_copy.index
test_svdimp.columns = test_copy.columns

# %%
cat_cols = list(cats_dict.keys())
# cat_cols.extend([])
norm_cat_cols = [col for col in train_svdimp.columns if col not in norm_dict['means'].keys()]

# %%
norm_cat_cols
# Out:
# ['application_type',
#  'purpose',
#  'sub_grade',
#  'addr_state',
#  'is_inc_v_joint',
#  'is_inc_v',
#  'grade',
#  'emp_length',
#  'disbursement_method',
#  'addr_zip',
#  'home_ownership',
#  'initial_list_status',
#  'earliest_cr_lineYear',
#  'earliest_cr_lineMonth',
#  'earliest_cr_lineWeek',
#  'earliest_cr_lineDayofweek',
#  'earliest_cr_lineDayofyear',
#  'earliest_cr_lineIs_quarter_start',
#  'earliest_cr_lineIs_year_start']

# %%
cat_cols
# Out:
# ['application_type',
#  'purpose',
#  'sub_grade',
#  'addr_state',
#  'is_inc_v_joint',
#  'is_inc_v',
#  'grade',
#  'emp_length',
#  'disbursement_method',
#  'addr_zip',
#  'home_ownership',
#  'initial_list_status']

# %%
# train_svdimp[[col for col in train_svdimp.columns if col not in cat_cols]]
train_svdimp[cat_cols]
# Out:
#          application_type  purpose  sub_grade  addr_state  is_inc_v_joint  \
# 0                     1.0      3.0        9.0         5.0             0.0
# 1                     1.0      3.0       27.0        15.0             0.0
# 3                     1.0      2.0       10.0        35.0             0.0
# 4                     1.0      5.0        2.0        30.0             0.0
# 5                     1.0      3.0       27.0         5.0             0.0
# 6                     1.0      3.0        8.0        25.0             0.0
# 7                     1.0      3.0       18.0        35.0             0.0
# 8                     1.0      3.0       12.0        44.0             0.0
# 9                     1.0      3.0       13.0         7.0             0.0
# 10                    1.0      3.0       19.0        40.0             0.0
# 11                    1.0      3.0        8.0         5.0             0.0
# 12                    1.0      2.0       15.0        44.0             0.0
# 13                    1.0      2.0        5.0        44.0             0.0
# 14                    1.0      3.0       17.0        21.0             0.0
# 15                    1.0      3.0        6.0        20.0             0.0
# 16                    1.0      3.0       20.0        44.0             0.0
# 17                    1.0      4.0       28.0        41.0             0.0
# 18                    1.0      3.0       23.0        36.0             0.0
# 19                    1.0      3.0       19.0        22.0             0.0
# 20                    1.0      5.0        3.0        15.0             0.0
# 21                    1.0      1.0        6.0        23.0             0.0
# 22                    1.0      3.0       23.0        35.0             0.0
# 23                    1.0      5.0       12.0         5.0             0.0
# 25                    1.0      3.0       19.0        25.0             0.0
# 26                    1.0      3.0       10.0        18.0             0.0
# 27                    1.0      3.0       14.0        26.0             0.0
# 28                    1.0      3.0        9.0         5.0             0.0
# 29                    1.0      3.0       18.0        17.0             0.0
# 30                    1.0      2.0        2.0         7.0             0.0
# 31                    1.0     10.0       23.0         8.0             0.0
# ...                   ...      ...        ...         ...             ...
# 1106009               1.0      3.0       24.0        26.0             0.0
# 1106523               1.0     13.0       16.0        38.0             0.0
# 1106541               1.0      5.0       22.0        20.0             0.0
# 1106869               1.0      3.0       16.0        24.0             0.0
# 1106878               1.0     10.0       20.0        10.0             0.0
# 1106900               1.0      3.0       21.0         7.0             0.0
# 1106931               1.0     10.0       18.0        39.0             0.0
# 1106949               1.0      7.0       16.0         7.0             0.0
# 1107476               1.0      3.0       23.0        23.0             0.0
# 1107495               1.0      3.0       20.0        11.0             0.0
# 1107506               1.0      3.0       18.0        39.0             0.0
# 1107510               1.0     10.0       23.0        24.0             0.0
# 1107524               1.0      3.0       19.0        19.0             0.0
# 1107787               1.0      3.0       16.0        23.0             0.0
# 1107809               1.0      2.0       17.0        21.0             0.0
# 1108063               1.0      3.0       20.0        41.0             0.0
# 1108074               1.0      3.0       23.0         5.0             0.0
# 1108086               1.0      3.0       19.0        44.0             0.0
# 1108094               1.0      2.0       16.0         5.0             0.0
# 1108098               1.0      3.0       18.0         4.0             0.0
# 1108148               1.0     12.0       29.0        10.0             0.0
# 1108161               1.0      3.0       21.0        32.0             0.0
# 1108193               1.0      3.0       16.0        32.0             0.0
# 1108240               1.0      3.0       21.0        10.0             0.0
# 1108256               1.0      3.0       16.0         5.0             0.0
# 1108392               1.0      9.0       16.0        44.0             0.0
# 1108393               1.0      3.0       22.0        24.0             0.0
# 1108407               1.0      3.0       20.0         2.0             0.0
# 1108464               1.0      8.0       16.0        39.0             0.0
# 1108584               1.0      3.0       21.0        19.0             0.0
#
#          is_inc_v  grade  emp_length  disbursement_method  addr_zip  \
# 0             2.0    2.0        11.0                  1.0     879.0
# 1             1.0    6.0        11.0                  1.0     566.0
# 3             1.0    2.0        11.0                  1.0     103.0
# 4             1.0    1.0         2.0                  1.0     649.0
# 5             2.0    6.0         2.0                  1.0     894.0
# 6             3.0    2.0         2.0                  1.0     622.0
# 7             2.0    4.0         1.0                  1.0      91.0
# 8             1.0    3.0         2.0                  1.0     731.0
# 9             1.0    3.0         7.0                  1.0      59.0
# 10            3.0    4.0        10.0                  1.0      21.0
# 11            1.0    2.0         4.0                  1.0     859.0
# 12            1.0    3.0         4.0                  1.0     729.0
# 13            1.0    1.0        11.0                  1.0     729.0
# 14            1.0    4.0         1.0                  1.0     196.0
# 15            1.0    2.0         6.0                  1.0      14.0
# 16            1.0    4.0         8.0                  1.0     724.0
# 17            2.0    6.0         1.0                  1.0     281.0
# 18            1.0    5.0        11.0                  1.0     438.0
# 19            3.0    4.0         3.0                  1.0      42.0
# 20            1.0    1.0         6.0                  1.0     595.0
# 21            1.0    2.0        11.0                  1.0     464.0
# 22            2.0    5.0         4.0                  1.0     135.0
# 23            1.0    3.0         2.0                  1.0     850.0
# 25            1.0    4.0         9.0                  1.0     596.0
# 26            1.0    2.0         4.0                  1.0     388.0
# 27            1.0    3.0         2.0                  1.0     373.0
# 28            1.0    2.0        11.0                  1.0     864.0
# 29            1.0    4.0         4.0                  1.0     625.0
# 30            3.0    1.0         2.0                  1.0      56.0
# 31            1.0    5.0        11.0                  1.0     190.0
# ...           ...    ...         ...                  ...       ...
# 1106009       2.0    5.0         2.0                  1.0     373.0
# 1106523       2.0    4.0         2.0                  1.0     907.0
# 1106541       2.0    5.0         0.0                  1.0      11.0
# 1106869       1.0    4.0        10.0                  1.0     521.0
# 1106878       2.0    4.0         6.0                  1.0     308.0
# 1106900       3.0    5.0        10.0                  1.0      52.0
# 1106931       3.0    4.0         2.0                  1.0     161.0
# 1106949       3.0    4.0         1.0                  1.0      60.0
# 1107476       1.0    5.0         7.0                  1.0     471.0
# 1107495       2.0    4.0         5.0                  1.0     290.0
# 1107506       2.0    4.0         2.0                  1.0     171.0
# 1107510       3.0    5.0         5.0                  1.0     530.0
# 1107524       1.0    4.0         6.0                  1.0     657.0
# 1107787       2.0    4.0         3.0                  1.0     467.0
# 1107809       3.0    4.0         2.0                  1.0     196.0
# 1108063       3.0    4.0         4.0                  1.0     281.0
# 1108074       1.0    5.0         2.0                  1.0     897.0
# 1108086       2.0    4.0         4.0                  1.0     714.0
# 1108094       2.0    4.0         5.0                  1.0     892.0
# 1108098       2.0    4.0         9.0                  1.0     802.0
# 1108148       3.0    6.0         5.0                  1.0     316.0
# 1108161       1.0    5.0         2.0                  1.0      80.0
# 1108193       2.0    4.0        11.0                  1.0      62.0
# 1108240       2.0    5.0        11.0                  1.0     336.0
# 1108256       3.0    4.0         2.0                  1.0     858.0
# 1108392       3.0    4.0         6.0                  1.0     714.0
# 1108393       1.0    5.0         2.0                  1.0     521.0
# 1108407       1.0    4.0         2.0                  1.0     339.0
# 1108464       3.0    4.0         2.0                  1.0     152.0
# 1108584       2.0    5.0         9.0                  1.0     657.0
#
#          home_ownership  initial_list_status
# 0                   4.0                  1.0
# 1                   4.0                  1.0
# 3                   4.0                  1.0
# 4                   1.0                  2.0
# 5                   1.0                  1.0
# 6                   1.0                  2.0
# 7                   4.0                  1.0
# 8                   3.0                  1.0
# 9                   4.0                  1.0
# 10                  4.0                  1.0
# 11                  4.0                  1.0
# 12                  1.0                  1.0
# 13                  1.0                  1.0
# 14                  4.0                  1.0
# 15                  4.0                  1.0
# 16                  4.0                  1.0
# 17                  4.0                  1.0
# 18                  1.0                  1.0
# 19                  4.0                  2.0
# 20                  1.0                  2.0
# 21                  1.0                  1.0
# 22                  4.0                  1.0
# 23                  1.0                  1.0
# 25                  1.0                  1.0
# 26                  4.0                  1.0
# 27                  1.0                  1.0
# 28                  4.0                  1.0
# 29                  1.0                  1.0
# 30                  1.0                  2.0
# 31                  1.0                  1.0
# ...                 ...                  ...
# 1106009             1.0                  1.0
# 1106523             1.0                  2.0
# 1106541             3.0                  1.0
# 1106869             1.0                  1.0
# 1106878             3.0                  1.0
# 1106900             1.0                  1.0
# 1106931             3.0                  1.0
# 1106949             4.0                  1.0
# 1107476             3.0                  2.0
# 1107495             4.0                  2.0
# 1107506             3.0                  1.0
# 1107510             1.0                  1.0
# 1107524             3.0                  2.0
# 1107787             1.0                  2.0
# 1107809             1.0                  1.0
# 1108063             1.0                  2.0
# 1108074             1.0                  2.0
# 1108086             1.0                  1.0
# 1108094             1.0                  2.0
# 1108098             4.0                  1.0
# 1108148             4.0                  1.0
# 1108161             1.0                  1.0
# 1108193             1.0                  1.0
# 1108240             1.0                  2.0
# 1108256             4.0                  1.0
# 1108392             4.0                  2.0
# 1108393             4.0                  2.0
# 1108407             1.0                  1.0
# 1108464             1.0                  2.0
# 1108584             1.0                  1.0
#
# [916089 rows x 12 columns]

# %% [markdown]
# # test that catboost works

# %%
# X_train = train_df
X_train = train_svdimp
y_train = eval_loan_info[eval_loan_info['id'].isin(train_ids)]['target_strict']

# X_test = test_df
X_test = test_svdimp
y_test = eval_loan_info[eval_loan_info['id'].isin(test_ids)]['target_strict']

# %%
from sklearn.metrics import accuracy_score
from catboost import CatBoostClassifier, Pool, cv
from sklearn.metrics import roc_curve, roc_auc_score

# %%
categorical_features_indices = [X_train.columns.get_loc(col) for col in norm_cat_cols]

# %%
# catboost complained about floats super close to 0, set values
# below thrsh to 0
# thrsh = 1e-6
# mask = X_train < thrsh
# X_train[mask] = 0

# mask = X_test < thrsh
# X_test[mask] = 0

# round to nearest int for categorical feature indices because svd_imp left floats where ints are expected
for col in categorical_features_indices:
    X_train.iloc[:,col] = X_train.iloc[:,col].round()
    X_test.iloc[:,col] = X_test.iloc[:,col].round()

# %%
params = {
    'iterations': 1000,
    'learning_rate': 0.1,
    'eval_metric': 'Accuracy',
#     'random_seed': 42,
    'logging_level': 'Silent',
    'use_best_model': True,
    'task_type': 'GPU',
#     'nan_mode': 'Min',
}
train_pool = Pool(X_train, y_train, cat_features=categorical_features_indices)
validate_pool = Pool(X_test, y_test, cat_features=categorical_features_indices)

# %%
cat_model = CatBoostClassifier(**params)
cat_model.fit(train_pool, eval_set=validate_pool)

# %%
def make_roc_plot(y_true, y_preds):
    '''
    y_true is 1-d array
    y_preds is 1-d array
    makes and shows roc_auc plot
    '''
    fpr, tpr, _ = roc_curve(y_true, y_preds)
    auc_score = roc_auc_score(y_true, y_preds)
    plt.plot(fpr, tpr, color='darkorange', label = 'ROC curve (area = {0})'.format(auc_score) )
    plt.plot([0, 1], [0, 1], color='navy', linestyle='--')
    plt.legend(loc='lower right')
    plt.show()
    
def make_feat_imp_plot(model, model_type, data, n_bar=15, ylim=.75, imp_thrsh=.9,figsize=(12,9)):
    '''
    Makes a plot of feature importances using data
    model = model (sklearn randomforest, lightgbm, or catboost)
    model_type: str; 'sklearn-rf', 'lightgbm', or 'catboost'
    data = pool from catboost, df for others
    top_n = top n features to plot. Default is None which plots all. Can pass float as well and will calculate top_n rounded to nearest int.
    '''
    feat_names, imps = get_feature_importances_and_names(model, data, model_type)

    df = pd.DataFrame.from_dict({'feat': feat_names,
                                    'imps': imps})
    df['norm_imps'] = df['imps']/df['imps'].sum()
    df['cum_imps'] = np.cumsum(df['norm_imps'])
    fig, ax = plt.subplots(nrows=2, ncols=1, figsize=figsize)
    ax[0].barh(list(reversed(list(df.index[:n_bar]))), 
            df['norm_imps'].head(n_bar), 
            align = 'center', edgecolor = 'k')
    # Set the yticks and labels
    ax[0].set_yticks(list(reversed(list(df.index[:n_bar]))))
    ax[0].set_yticklabels(df['feat'].head(n_bar))
    ax[0].set_xlabel('Normalized Importance')
    ax[0].set_title('Feature Importances')
    ax[1].plot(list(range(len(df))), df['cum_imps'], 'r-')
    ax[1].set_ylabel('Cumulative Feature Importance')
    ax[1].set_xlabel('Number of Features')
    ax[1].set_title('Cumulative Features')
    ax[1].set_ylim(ylim,1.01)
    fig.tight_layout()
    plt.show()
    
    return df

# %%
# hyperlearn SVD imputation no making null_ind_cols, cat cols were all cols that did not have entries in norm_dict meaning they weren't cols that were standardized/normalized and thus should be categorical
# X_cat_nanfilled, typical best seen is .723ish (norm_cat_cols)
predictions_probs = cat_model.predict_proba(X_test)
make_roc_plot(y_test, predictions_probs[:,1])
print('best number of trees/iterations: {0}'.format(cat_model.tree_count_))
# Out:
# best number of trees/iterations: 631

# %%
# hyperlearn SVD imputation no making null_ind_cols, and cat_cols from cat_dict.keys() instead of not being in norm_dict
# X_cat_nanfilled, typical best seen is .723ish (cat cols)
predictions_probs = cat_model.predict_proba(X_test)
make_roc_plot(y_test, predictions_probs[:,1])
print('best number of trees/iterations: {0}'.format(cat_model.tree_count_))
# Out:
# best number of trees/iterations: 848

# %%
# hyperlearn SVD imputation
# X_cat_nanfilled, typical best seen is .7177ish
predictions_probs = cat_model.predict_proba(X_test)
make_roc_plot(y_test, predictions_probs[:,1])
print('best number of trees/iterations: {0}'.format(cat_model.tree_count_))
# Out:
# best number of trees/iterations: 702

# %%
# justin filling nan version
# X_cat_nanfilled, typical best seen is .7186ish
predictions_probs = cat_model.predict_proba(X_test)
make_roc_plot(y_test, predictions_probs[:,1])
print('best number of trees/iterations: {0}'.format(cat_model.tree_count_))
# Out:
# best number of trees/iterations: 464
